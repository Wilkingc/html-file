# %% [markdown]
# <a href="https://colab.research.google.com/github/Wilkingc/html-file/blob/main/Class_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
module1 = {
    "Module_1_A" : ("""1a-Markdown.ipynb
1b-Colab.Basics.and.Example.Notebooks.ipynb
1bx-1a-Markdown.About.Me.Exercise.ipynb.exercise.stub
1c-Intro.Python.ipynb
1cx-1b-Intro.Python.Exercises.ipynb.exercise.stub
1d-Lists.ipynb
1dx-1c-Lists.Exercises.ipynb.exercise.stub
1dx-1d-Intro.to.Python,Lists.ipynb.stub
1e-Intro.to.Data.Science.pptx
1f-Data.Science.Process.and.Problem.Definition.pptx
1g-Data.Science.Mistakes.pptx
1gx-1e-Data.Science.Problem.Definition.Exercises.ipynb.exercise.stub
2a-Conditionals.ipynb
2a1-Debugging.Tips.ipynb
2ax-2a-Conditionals.Exercises.ipynb.exercise.stub
2b-Dictionaries,Sets,Tuples.ipynb
2bx-2b-Lists,Dictionaries,Sets,Tuples.Exercises.ipynb.exercise.stub
2by-2a-Conditionals,Dictionaries,Loops.ipynb.py.stub
2c-Loops.ipynb
2d-Intro.to.Stats.pptx
2e-Intro.to.Stats.ipynb
2f-Intro.to.Probability.pptx
2g-Bayes.Theorem.pptx
3a-Functions.ipynb
3b-Pandas.ipynb
np.NaN
""").split(),
           "Exercices_1_A":("""1a-Markdown.About.Me.Exercise.ipynb
1b-Intro.Python.Exercise.ipynb
1c-Lists.Exercise.ipynb
1d-Intro.to.Python,Lists.Exercise.ipynb
1e-Data.Science.Problem.Definition.Exercise.ipynb
2a-Conditionals.Exercise.ipynb
2b-Loop.Exercise.ipynb
2c-Conditionals,Dictionaries,Loops.Exercise.ipynb""").split(),
           "Module_1_B": ("""3c-Data.Cleaning.and.EDA.pptx
3d-Data.Cleaning.and.EDA.ipynb
3dx-3a-EDA.Exercise.ipynb.exercise.stub
4a-Cross.Validation.and.Metrics.for.Categorical.Response.pptx
4b-pt1-Naive.Bayes.pptx
4c-pt1-Naive.Bayes.ipynb
4d-pt2-Naive.Bayes.pptx
4e-pt2-Naive.Bayes.ipynb
4f-pt3-Naive.Bayes.pptx
4g-pt3-Naive.Bayes.ipynb
4h-Tables.how.many.ipynb
5a-Numpy.ipynb
5b-Matplotlib.ipynb
5c-IDA-triage.ipynb
6a-More.Indexing.in.Pandas.ipynb
6b1-Pandas.Importing.and.Exporting.ipynb
6b2-Pandas.Importing.HTML.tax.ipynb
6bx-5a-Pandas.Exercise.ipynb.stub
6c-Bias.Variance.Trade.Off.pptx
6d-Underfitting.and.Overfitting.and.CV.ipynb
7a-Slidesmanship.pptx
8b-Probability.Distributions.pptx
8c-Probability.Distributions.ipynb
8d-Pandas.Unnest.ipynb
8e-Pandas.Unpivot.ipynb
stdev.walkthrough.ipynb """).split(),
    "Exercices_1_B":("""2d-Lists,Dictionaries,Sets,Tuples.Exercise.ipynb
3a-Functions.Exercise.ipynb
3b-EDA.Exercise.ipynb
4a-Bayes.Rule.Exercise.ipynb
5a-Numpy.Exercise.ipynb
5b-Pandas.Exercise.ipynb
6a-Numpy,Pandas,Plotting.Exercise.ipynb""").split()}

# %%
m1 = pd.DataFrame.from_dict(module1, orient='index').transpose()
m1
# Out:
#                                            Module_1_A  \
# 0                                   1a-Markdown.ipynb
# 1         1b-Colab.Basics.and.Example.Notebooks.ipynb
# 2   1bx-1a-Markdown.About.Me.Exercise.ipynb.exerci...
# 3                               1c-Intro.Python.ipynb
# 4   1cx-1b-Intro.Python.Exercises.ipynb.exercise.stub
# 5                                      1d-Lists.ipynb
# 6          1dx-1c-Lists.Exercises.ipynb.exercise.stub
# 7             1dx-1d-Intro.to.Python,Lists.ipynb.stub
# 8                       1e-Intro.to.Data.Science.pptx
# 9   1f-Data.Science.Process.and.Problem.Definition...
# 10                      1g-Data.Science.Mistakes.pptx
# 11  1gx-1e-Data.Science.Problem.Definition.Exercis...
# 12                              2a-Conditionals.ipynb
# 13                           2a1-Debugging.Tips.ipynb
# 14  2ax-2a-Conditionals.Exercises.ipynb.exercise.stub
# 15                  2b-Dictionaries,Sets,Tuples.ipynb
# ...

# %%
module2 = {"Module_2_A": ("""1a-Model.Validation.of.Continuous.Response.pptx
1b-Model.Validation.of.Continuous.Response.ipynb
1c-Linear.Regression.pptx
1d-Linear.Regression.ipynb
1e-Imputation.ipynb
2a-Encoding.ipynb
2b-Feature.Scaling.ipynb
2c-Interpolation.vs.Extrapolation.ipynb
2d-Advanced_Pandas.ipynb""").split(),
      "Exercice_2_A" : ("1a-Numpy.and.Plotting.ipynb".split()),
           "Module_2_B" : ("""3a-Regularization.pptx
3b-Regularization_Example.ipynb
3c-Feature_Selection.ipynb
3c-Feature_Selection.scaling.ipynb
4a-Plotly_Express.ipynb
5a-Box_Cox.ipynb
5b-Logistic.Regression.pptx
5c-Logistic.Regression.Example.ipynb""").split(),
      "Exercice_2_B" : ("2a-Games.ipynb").split()}

# %%
m2 = pd.DataFrame.from_dict(module2, orient='index').transpose()
m2
# Out:
#                                          Module_2_A  \
# 0   1a-Model.Validation.of.Continuous.Response.pptx
# 1  1b-Model.Validation.of.Continuous.Response.ipynb
# 2                         1c-Linear.Regression.pptx
# 3                        1d-Linear.Regression.ipynb
# 4                               1e-Imputation.ipynb
# 5                                 2a-Encoding.ipynb
# 6                          2b-Feature.Scaling.ipynb
# 7           2c-Interpolation.vs.Extrapolation.ipynb
# 8                          2d-Advanced_Pandas.ipynb
#
#                   Exercice_2_A                            Module_2_B  \
# 0  1a-Numpy.and.Plotting.ipynb                3a-Regularization.pptx
# 1                         None       3b-Regularization_Example.ipynb
# 2                         None            3c-Feature_Selection.ipynb
# 3                         None    3c-Feature_Selection.scaling.ipynb
# 4                         None               4a-Plotly_Express.ipynb
# ...

# %%
module3 = {
    "Module_3_A" : ("""1a-Mock.Interview.Questions.docx
1b-Mock.Interview.Answers
1c-Coding.Interview.Tips.ipynb
1d-HTTP.HTML.Trees.ipynb
1e-JSON.Fields.ipynb
1f-YAML.JSON.ipynb
2a-magics.ipynb
2b-SQL.Introduction.pptx
2c-sqlite3.create.db.ipynb
2d-sqlite3-Selects.ipynb
2e-sqlite3-Joins.ipynb""").split(),
           "Exercice_3_A" : ("""1a-Empire.State.Building.Game.ipynb
2a-Grangers.Elf.Analysis.ipynb""").split(),
    "Module_3_B" : ("""2f-sqlite3-chinook.db.ipynb
3a-GCP.gcloud.ipynb
3b-BigQuery.metadata.ipynb
3c-BigQuery.Getting.Started.ipynb
3d-BigQuery-Selects.ipynb
3d_BigQuery_Selects.kaggle.ipynb
3e-BigQuery-Joins.ipynb
4a-Regular.Expressions.ipynb
4b-GitHub.and.git.with.Google.Colab.ipynb
4c-Metadata.DataFrames.Module.ABQ.Busn.ipynb
4c-Metadata.DataFrames.ipynb""").split(),
            "Exercice_3_B" : ("3a-Tools.ipynb").split()}

# %%
m3 = pd.DataFrame.from_dict(module3, orient='index').transpose()
m3
# Out:
#                           Module_3_A                         Exercice_3_A  \
# 0   1a-Mock.Interview.Questions.docx  1a-Empire.State.Building.Game.ipynb
# 1          1b-Mock.Interview.Answers       2a-Grangers.Elf.Analysis.ipynb
# 2     1c-Coding.Interview.Tips.ipynb                                 None
# 3           1d-HTTP.HTML.Trees.ipynb                                 None
# 4               1e-JSON.Fields.ipynb                                 None
# 5                 1f-YAML.JSON.ipynb                                 None
# 6                    2a-magics.ipynb                                 None
# 7           2b-SQL.Introduction.pptx                                 None
# 8         2c-sqlite3.create.db.ipynb                                 None
# 9           2d-sqlite3-Selects.ipynb                                 None
# 10            2e-sqlite3-Joins.ipynb                                 None
#
#                                       Module_3_B    Exercice_3_B
# ...
